# %%
"""
1. Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`. 
After generating the list, find the following:
 (i) Write a Python function to calculate the mean of a given list of numbers.
 Create a function to find the median of a list of numbers.
 (ii) Develop a program to compute the mode of a list of integers.
 (iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights.
 (iv) Write a Python function to find the geometric mean of a list of positive numbers.
 (v) Create a program to calculate the harmonic mean of a list of values.
 (vi) Build a function to determine the midrange of a list of numbers (average of the minimum and maximum).
 (vii) Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of outliers.
 """


#### Generate a List of 100 Integers

import random

# Generate a list of 100 random integers between 90 and 130
int_list = [random.randint(90, 130) for _ in range(100)]
print(int_list)




#### (i): Calculate Mean and Median
#### Mean

def calculate_mean(numbers):
    return sum(numbers) / len(numbers)

# Example usage
mean_value = calculate_mean(int_list)
print("Mean:", mean_value)

#### Median
def calculate_median(numbers):
    sorted_numbers = sorted(numbers)
    n = len(numbers)
    if n % 2 == 0:
        median_value = (sorted_numbers[n//2 - 1] + sorted_numbers[n//2]) / 2
    else:
        median_value = sorted_numbers[n//2]
    return median_value

# Example usage
median_value = calculate_median(int_list)
print("Median:", median_value)




#### (ii): Compute the Mode

from collections import Counter

def calculate_mode(numbers):
    count = Counter(numbers)
    mode_value = count.most_common(1)[0][0]
    return mode_value

# Example usage
mode_value = calculate_mode(int_list)
print("Mode:", mode_value)




#### (iii): Calculate Weighted Mean

def calculate_weighted_mean(values, weights):
    weighted_sum = sum(v * w for v, w in zip(values, weights))
    return weighted_sum / sum(weights)

# Example usage
weights = [random.randint(1, 10) for _ in range(100)]
weighted_mean = calculate_weighted_mean(int_list, weights)
print("Weighted Mean:", weighted_mean)




#### (iv): Calculate Geometric Mean
import math

def calculate_geometric_mean(numbers):
    product = 1
    for num in numbers:
        product *= num
    return product ** (1 / len(numbers))

# Example usage
geometric_mean = calculate_geometric_mean(int_list)
print("Geometric Mean:", geometric_mean)




#### (v): Calculate Harmonic Mean
def calculate_harmonic_mean(numbers):
    return len(numbers) / sum(1 / num for num in numbers)

# Example usage
harmonic_mean = calculate_harmonic_mean(int_list)
print("Harmonic Mean:", harmonic_mean)




#### (vi): Calculate Midrange
def calculate_midrange(numbers):
    return (min(numbers) + max(numbers)) / 2

# Example usage
midrange_value = calculate_midrange(int_list)
print("Midrange:", midrange_value)




#### (vii): Trimmed Mean (Exclude a Percentage of Outliers)
def calculate_trimmed_mean(numbers, percentage):
    sorted_numbers = sorted(numbers)
    trim_amount = int(len(numbers) * percentage / 100)
    trimmed_numbers = sorted_numbers[trim_amount: -trim_amount]
    return calculate_mean(trimmed_numbers)

# Example usage
trimmed_mean_value = calculate_trimmed_mean(int_list, 10)  # Exclude top and bottom 10% of outliers
print("Trimmed Mean:", trimmed_mean_value)
# Out:
# [94, 114, 104, 124, 90, 129, 116, 118, 107, 91, 92, 112, 94, 92, 126, 111, 110, 104, 114, 115, 121, 107, 123, 103, 107, 107, 110, 101, 129, 124, 114, 91, 101, 116, 118, 116, 98, 123, 94, 117, 107, 93, 120, 123, 104, 98, 118, 117, 117, 128, 97, 103, 130, 122, 109, 100, 103, 125, 99, 90, 100, 116, 99, 115, 94, 96, 115, 92, 106, 98, 119, 125, 130, 119, 117, 125, 103, 111, 112, 103, 129, 129, 107, 128, 116, 129, 95, 126, 116, 95, 111, 109, 130, 97, 111, 101, 117, 111, 102, 130]
# Mean: 110.64
# Median: 111.0
# Mode: 116
# Weighted Mean: 111.20701754385965
# Geometric Mean: 110.00947166567087
# Harmonic Mean: 109.37470963658848
# Midrange: 110.0
# Trimmed Mean: 110.65

# %%
"""
2. Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`. After generating the list, find the following:
 (i) Compare the given list of visualization for the given data:
 	1. Frequency & Gaussian distribution
 	2. Frequency smoothened KDE plot
 	3. Gaussian distribution & smoothened KDE plot
 (ii) Write a Python function to calculate the range of a given list of numbers.
 (iii) Create a program to find the variance and standard deviation of a list of numbers.
 (iv) Implement a function to compute the interquartile range (IQR) of a list of values.
 (v) Build a program to calculate the coefficient of variation for a dataset.
 (vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.
 (vii) Create a program to calculate the quartile deviation of a list of values.
 (viii) Implement a function to find the range-based coefficient of dispersion for a dataset.
 """



#### Generate a List of 500 Integers
import random

# Generate a list of 500 random integers between 200 and 300
int_list2 = [random.randint(200, 300) for _ in range(500)]
print(int_list2)




#### (i): Visualizations for the Given Data
#### 1. Frequency & Gaussian Distribution:

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Plot frequency distribution (histogram) and Gaussian distribution
plt.figure(figsize=(10, 6))
sns.histplot(int_list2, kde=False, color='blue', label="Frequency", bins=30)
sns.kdeplot(int_list2, color='red', label="Gaussian distribution", linestyle='--')
plt.title("Frequency & Gaussian Distribution")
plt.legend()
plt.show()


#### 2. Frequency Smoothened KDE Plot

# Plot frequency distribution (histogram) and smoothened KDE plot
plt.figure(figsize=(10, 6))
sns.histplot(int_list2, kde=False, color='blue', bins=30, label="Frequency")
sns.kdeplot(int_list2, color='green', label="KDE")
plt.title("Frequency & KDE Plot")
plt.legend()
plt.show()


#### 3. Gaussian Distribution & Smoothened KDE Plot

# Plot Gaussian distribution and smoothened KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(int_list2, color='green', label="KDE")
sns.kdeplot(np.random.normal(np.mean(int_list2), np.std(int_list2), len(int_list2)), color='red', label="Gaussian")
plt.title("Gaussian Distribution & KDE Plot")
plt.legend()
plt.show()



#### (ii): Calculate the Range of a List
def calculate_range(numbers):
    return max(numbers) - min(numbers)

# Example usage
range_value = calculate_range(int_list2)
print("Range:", range_value)




#### (iii): Variance and Standard Deviation

def calculate_variance(numbers):
    mean = sum(numbers) / len(numbers)
    variance = sum((x - mean) ** 2 for x in numbers) / len(numbers)
    return variance

def calculate_standard_deviation(numbers):
    variance = calculate_variance(numbers)
    return variance ** 0.5

# Example usage
variance_value = calculate_variance(int_list2)
std_dev_value = calculate_standard_deviation(int_list2)
print("Variance:", variance_value)
print("Standard Deviation:", std_dev_value)




#### (iv): Compute Interquartile Range (IQR)

def calculate_iqr(numbers):
    sorted_numbers = sorted(numbers)
    q1 = np.percentile(sorted_numbers, 25)
    q3 = np.percentile(sorted_numbers, 75)
    return q3 - q1

# Example usage
iqr_value = calculate_iqr(int_list2)
print("Interquartile Range (IQR):", iqr_value)




#### (v): Coefficient of Variation

def calculate_coefficient_of_variation(numbers):
    mean = sum(numbers) / len(numbers)
    std_dev = calculate_standard_deviation(numbers)
    return (std_dev / mean) * 100

# Example usage
cv_value = calculate_coefficient_of_variation(int_list2)
print("Coefficient of Variation (%):", cv_value)




#### (vi): Mean Absolute Deviation (MAD)

def calculate_mad(numbers):
    mean = sum(numbers) / len(numbers)
    mad = sum(abs(x - mean) for x in numbers) / len(numbers)
    return mad

# Example usage
mad_value = calculate_mad(int_list2)
print("Mean Absolute Deviation (MAD):", mad_value)




#### (vii): Quartile Deviation

def calculate_quartile_deviation(numbers):
    sorted_numbers = sorted(numbers)
    q1 = np.percentile(sorted_numbers, 25)
    q3 = np.percentile(sorted_numbers, 75)
    return (q3 - q1) / 2

# Example usage
quartile_deviation_value = calculate_quartile_deviation(int_list2)
print("Quartile Deviation:", quartile_deviation_value)




#### (viii): Range-Based Coefficient of Dispersion

def calculate_range_based_coefficient_of_dispersion(numbers):
    range_value = calculate_range(numbers)
    mean = sum(numbers) / len(numbers)
    return (range_value / mean) * 100

# Example usage
range_dispersion_value = calculate_range_based_coefficient_of_dispersion(int_list2)
print("Range-based Coefficient of Dispersion (%):", range_dispersion_value)
# Out:
# [272, 297, 268, 217, 236, 233, 251, 286, 260, 280, 274, 240, 211, 229, 270, 247, 297, 211, 240, 278, 211, 239, 263, 282, 217, 278, 227, 232, 273, 212, 246, 229, 237, 284, 274, 272, 215, 287, 244, 270, 279, 293, 260, 216, 220, 276, 290, 263, 207, 209, 274, 244, 271, 264, 218, 226, 237, 213, 295, 204, 255, 229, 202, 293, 241, 257, 299, 202, 295, 275, 224, 211, 244, 261, 229, 291, 294, 267, 239, 251, 232, 263, 219, 212, 269, 280, 214, 239, 285, 206, 282, 272, 297, 229, 300, 219, 213, 295, 266, 276, 224, 224, 265, 251, 224, 238, 233, 259, 269, 234, 230, 269, 259, 214, 204, 258, 224, 254, 273, 296, 236, 262, 276, 278, 227, 275, 215, 250, 204, 233, 235, 269, 290, 220, 276, 234, 240, 253, 203, 258, 218, 229, 299, 280, 255, 296, 284, 258, 226, 222, 214, 234, 221, 243, 230, 234, 285, 276, 218, 292, 253, 257, 282, 264, 295, 285, 230, 217, 223, 221, 237, 215, 202, 298, 251, 261, 264, 259, 237, 289, 300, 226, 220, 289, 256, 232, 260, 254, 273, 297, 288, 292, 217, 256, 227, 214, 261, 200, 284, 24
# ...

# %%
#### 3. Write a Python class representing a discrete random variable with methods to calculate its expected value and variance.

class DiscreteRandomVariable:
    def __init__(self, values, probabilities):
        self.values = values
        self.probabilities = probabilities

    def expected_value(self):
        # Expected value: sum of value * probability
        return sum(value * prob for value, prob in zip(self.values, self.probabilities))

    def variance(self):
        # Variance: sum of (value - expected_value)^2 * probability
        mean = self.expected_value()
        return sum(prob * (value - mean) ** 2 for value, prob in zip(self.values, self.probabilities))


# Example usage
values = [1, 2, 3, 4, 5]
probabilities = [0.1, 0.2, 0.3, 0.2, 0.2]

rv = DiscreteRandomVariable(values, probabilities)
print("Expected Value:", rv.expected_value())
print("Variance:", rv.variance())
# Out:
# Expected Value: 3.2
# Variance: 1.56

# %%
#### 4. Implement a program to simulate the rolling of a fair six-sided die and calculate the expected value and variance of the outcomes.

import random

def roll_die(num_rolls):
    outcomes = [random.randint(1, 6) for _ in range(num_rolls)]
    return outcomes

def expected_value_die(outcomes):
    return sum(outcomes) / len(outcomes)

def variance_die(outcomes):
    mean = expected_value_die(outcomes)
    return sum((x - mean) ** 2 for x in outcomes) / len(outcomes)


# Simulate rolling a die 1000 times
outcomes = roll_die(1000)
print("Expected Value:", expected_value_die(outcomes))
print("Variance:", variance_die(outcomes))
# Out:
# Expected Value: 3.491
# Variance: 2.927919000000031

# %%
#### 5. Create a Python function to generate random samples from a given probability distribution (e.g., binomial, Poisson) and calculate their mean and variance.

#### Example: Binomial Distribution
import numpy as np

def generate_binomial_samples(n, p, size):
    samples = np.random.binomial(n, p, size)
    return samples

def mean_variance(samples):
    mean = np.mean(samples)
    variance = np.var(samples)
    return mean, variance

# Example usage: Binomial distribution with n=10 trials, p=0.5 probability, and 1000 samples
samples = generate_binomial_samples(10, 0.5, 1000)
mean, variance = mean_variance(samples)
print("Mean of Binomial Samples:", mean)
print("Variance of Binomial Samples:", variance)


#### Example: Poisson Distribution
def generate_poisson_samples(lam, size):
    samples = np.random.poisson(lam, size)
    return samples

# Example usage: Poisson distribution with λ=3 and 1000 samples
samples = generate_poisson_samples(3, 1000)
mean, variance = mean_variance(samples)
print("Mean of Poisson Samples:", mean)
print("Variance of Poisson Samples:", variance)
# Out:
# Mean of Binomial Samples: 4.972
# Variance of Binomial Samples: 2.4612160000000003
# Mean of Poisson Samples: 3.065
# Variance of Poisson Samples: 2.9207750000000003

# %%
#### 6. Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation of the samples.

import numpy as np

def generate_gaussian_samples(mean, std_dev, size):
    samples = np.random.normal(mean, std_dev, size)
    return samples

def calculate_statistics(samples):
    mean = np.mean(samples)
    variance = np.var(samples)
    std_dev = np.std(samples)
    return mean, variance, std_dev

# Example usage: Gaussian distribution with mean = 0, std_dev = 1, and 1000 samples
samples = generate_gaussian_samples(0, 1, 1000)
mean, variance, std_dev = calculate_statistics(samples)
print("Mean of Gaussian Samples:", mean)
print("Variance of Gaussian Samples:", variance)
print("Standard Deviation of Gaussian Samples:", std_dev)
# Out:
# Mean of Gaussian Samples: 0.05143408186358995
# Variance of Gaussian Samples: 0.9105094142611719
# Standard Deviation of Gaussian Samples: 0.9542061696830365

# %%
"""
7. Use seaborn library to load `tips` dataset. Find the following from the dataset for the columns `total_bill` 
and `tip`:
 (i) Write a Python function that calculates their skewness.
 (ii) Create a program that determines whether the columns exhibit positive skewness, negative skewness, or is approximately symmetric.
 (iii) Write a function that calculates the covariance between two columns.
 (iv) Implement a Python program that calculates the Pearson correlation coefficient between two columns.
 (v) Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using scatter plots.
 """

#### Loading the tips Dataset
import seaborn as sns
import pandas as pd
from scipy.stats import skew, pearsonr

# Load the 'tips' dataset
tips = sns.load_dataset('tips')

# Display the first few rows of the dataset
print(tips.head())



#### (i) Write a Python function that calculates skewness of total_bill and tip

def calculate_skewness(data, column):
    return skew(data[column])

# Calculate skewness for 'total_bill' and 'tip'
total_bill_skewness = calculate_skewness(tips, 'total_bill')
tip_skewness = calculate_skewness(tips, 'tip')

print("Skewness of total_bill:", total_bill_skewness)
print("Skewness of tip:", tip_skewness)




#### (ii) Determine whether the columns exhibit positive skewness, negative skewness, or are symmetric
"""
a. Positive Skewness: If skewness > 0, the distribution is positively skewed (right-skewed).
b. Negative Skewness: If skewness < 0, the distribution is negatively skewed (left-skewed).
c. Symmetric: If skewness ≈ 0, the distribution is approximately symmetric.
"""

def check_skewness(skewness_value):
    if skewness_value > 0:
        return "Positive skewness"
    elif skewness_value < 0:
        return "Negative skewness"
    else:
        return "Approximately symmetric"

# Check skewness of total_bill and tip
print("Total Bill:", check_skewness(total_bill_skewness))
print("Tip:", check_skewness(tip_skewness))




#### (iii) Write a function that calculates the covariance between total_bill and tip

def calculate_covariance(data, col1, col2):
    return data[[col1, col2]].cov().iloc[0, 1]

# Calculate covariance between 'total_bill' and 'tip'
covariance = calculate_covariance(tips, 'total_bill', 'tip')
print("Covariance between total_bill and tip:", covariance)




#### (iv) Implement a program to calculate the Pearson correlation coefficient

def calculate_pearson_correlation(data, col1, col2):
    corr, _ = pearsonr(data[col1], data[col2])
    return corr

# Calculate Pearson correlation between 'total_bill' and 'tip'
pearson_corr = calculate_pearson_correlation(tips, 'total_bill', 'tip')
print("Pearson Correlation between total_bill and tip:", pearson_corr)




#### (v) Visualize the correlation using scatter plots

import matplotlib.pyplot as plt

def scatter_plot(data, col1, col2):
    plt.figure(figsize=(8, 6))
    plt.scatter(data[col1], data[col2], alpha=0.5)
    plt.title(f"Scatter plot of {col1} vs {col2}")
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.show()

# Plot scatter plot between 'total_bill' and 'tip'
scatter_plot(tips, 'total_bill', 'tip')
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# Skewness of total_bill: 1.1262346334818638
# Skewness of tip: 1.4564266884221506
# Total Bill: Positive skewness
# Tip: Positive skewness
# Covariance between total_bill and tip: 8.323501629224854
# Pearson Correlation between total_bill and tip: 0.6757341092113647

# %%
#### 8. Write a Python function to calculate the probability density function (PDF) of a continuous random variable for a given normal distribution.

from scipy.stats import norm

def calculate_pdf(x, mean, std_dev):
    # Calculate the PDF of a normal distribution
    return norm.pdf(x, mean, std_dev)

# Example: Calculate the PDF for x = 1, mean = 0, standard deviation = 1
x_value = 1
mean = 0
std_dev = 1
pdf_value = calculate_pdf(x_value, mean, std_dev)
print(f"PDF at x = {x_value} for a normal distribution with mean = {mean} and std_dev = {std_dev} is: {pdf_value}")
# Out:
# PDF at x = 1 for a normal distribution with mean = 0 and std_dev = 1 is: 0.24197072451914337

# %%
#### 9.  Create a program to calculate the cumulative distribution function (CDF) of exponential distribution.

from scipy.stats import expon

def calculate_cdf_exponential(x, rate):
    # Calculate the CDF of an exponential distribution
    return expon.cdf(x, scale=1/rate)

# Example: Calculate the CDF for x = 2 and rate (lambda) = 0.5
x_value = 2
rate = 0.5
cdf_value = calculate_cdf_exponential(x_value, rate)
print(f"CDF at x = {x_value} for an exponential distribution with rate = {rate} is: {cdf_value}")
# Out:
# CDF at x = 2 for an exponential distribution with rate = 0.5 is: 0.6321205588285577

# %%
#### 10. Write a Python function to calculate the probability mass function (PMF) of Poisson distribution.

from scipy.stats import poisson

def calculate_pmf_poisson(k, rate):
    # Calculate the PMF of a Poisson distribution
    return poisson.pmf(k, rate)

# Example: Calculate the PMF for k = 3 and rate (lambda) = 2
k_value = 3
rate = 2
pmf_value = calculate_pmf_poisson(k_value, rate)
print(f"PMF for k = {k_value} with rate = {rate} in a Poisson distribution is: {pmf_value}")
# Out:
# PMF for k = 3 with rate = 2 in a Poisson distribution is: 0.18044704431548356

# %%
"""
11. A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors 
who make a purchase). They collect data from the old and new layouts to compare.
To generate the data use the following command:
```python
import numpy as np
# 50 purchases out of 1000 visitors
old_layout = np.array([1] * 50 + [0] * 950)
# 70 purchases out of 1000 visitors  
new_layout = np.array([1] * 70 + [0] * 930)
 ```
Apply z-test to find which layout is successful.
"""

import numpy as np
import statsmodels.api as sm

# Generate the data
old_layout = np.array([1] * 50 + [0] * 950)  # 50 purchases out of 1000 visitors
new_layout = np.array([1] * 70 + [0] * 930)  # 70 purchases out of 1000 visitors

# Proportions
n_old = len(old_layout)
n_new = len(new_layout)
p1 = old_layout.mean()  # Proportion of purchases in old layout
p2 = new_layout.mean()  # Proportion of purchases in new layout

# Perform z-test
count = np.array([sum(old_layout), sum(new_layout)])
nobs = np.array([n_old, n_new])
z_stat, p_value = sm.stats.proportions_ztest(count, nobs, alternative='larger')

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The new layout has a higher conversion rate.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference.")

    
"""
Interpretation:
- If the p-value is less than the significance level (e.g., 0.05), the new layout is statistically significantly better than the old layout.
- If the p-value is greater than 0.05, there is no significant difference between the two layouts.
"""
# Out:
# Z-statistic: -1.883108942886774
# P-value: 0.9701571972337869
# Fail to reject the null hypothesis. There is no significant difference.
# '\nInterpretation:\n- If the p-value is less than the significance level (e.g., 0.05), the new layout is statistically significantly better than the old layout.\n- If the p-value is greater than 0.05, there is no significant difference between the two layouts.\n'

# %%
"""
12.  A tutoring service claims that its program improves students' exam scores. A sample of students who 
participated in the program was taken, and their scores before and after the program were recorded.
Use the below code to generate samples of respective arrays of marks:
```python
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])
```
Use z-test to find if the claims made by tutor are true or false
"""

import numpy as np
import statsmodels.stats.weightstats as stests

# Data
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

# Calculate the differences
differences = after_program - before_program

# Perform z-test
z_stat, p_value = stests.ztest(differences, value=0, alternative='larger')

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The program significantly improves exam scores.")
else:
    print("Fail to reject the null hypothesis. There is no significant improvement in exam scores.")
    
    

"""
Interpretation:
- If the p-value is less than 0.05 (for a 5% significance level), we reject the null hypothesis and conclude that the tutoring program has significantly improved the students' exam scores.
- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no significant improvement.
"""
# Out:
# Z-statistic: 4.593190894944668
# P-value: 2.182597052671683e-06
# Reject the null hypothesis. The program significantly improves exam scores.
# "\nInterpretation:\n- If the p-value is less than 0.05 (for a 5% significance level), we reject the null hypothesis and conclude that the tutoring program has significantly improved the students' exam scores.\n- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no significant improvement.\n"

# %%
"""
13.  A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and after administering the drug.
Use the below code to generate samples of respective arrays of blood pressure:
```python
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])
```
Implement z-test to find if the drug really works or not.
"""

import numpy as np
import statsmodels.stats.weightstats as stests

# Data
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

# Calculate the differences
differences = before_drug - after_drug

# Perform z-test
z_stat, p_value = stests.ztest(differences, value=0, alternative='larger')

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The drug significantly reduces blood pressure.")
else:
    print("Fail to reject the null hypothesis. The drug does not significantly reduce blood pressure.")
    

"""
Interpretation:
- If the p-value is less than 0.05 (for a 5% significance level), we reject the null hypothesis and conclude that the drug significantly reduces blood pressure.
- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no significant reduction in blood pressure due to the drug.
"""
# Out:
# Z-statistic: 10.04987562112089
# P-value: 4.599172203850128e-24
# Reject the null hypothesis. The drug significantly reduces blood pressure.
# '\nInterpretation:\n- If the p-value is less than 0.05 (for a 5% significance level), we reject the null hypothesis and conclude that the drug significantly reduces blood pressure.\n- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no significant reduction in blood pressure due to the drug.\n'

# %%
"""
14. A customer service department claims that their average response time is less than 5 minutes. A sample of recent customer interactions was taken, and the response times were recorded.
Implement the below code to generate the array of response time:
```python
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])
```
Implement z-test to find the claims made by customer service department are true or false.
"""

import numpy as np
import statsmodels.stats.weightstats as stests

# Data
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])

# Perform z-test
z_stat, p_value = stests.ztest(response_times, value=5, alternative='smaller')

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The customer service department's claim is valid (average response time is less than 5 minutes).")
else:
    print("Fail to reject the null hypothesis. The customer service department's claim is not supported (average response time is not less than 5 minutes).")


    
"""
Interpretation:
- If the p-value is less than 0.05 (for a 5% significance level), we reject the null hypothesis and conclude that the customer service department's claim is true (the response time is less than 5 minutes).
- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no sufficient evidence to support the claim that the average response time is less than 5 minutes.
"""
# Out:
# Z-statistic: -3.1844572260429627
# P-value: 0.0007251287113068958
# Reject the null hypothesis. The customer service department's claim is valid (average response time is less than 5 minutes).
# "\nInterpretation:\n- If the p-value is less than 0.05 (for a 5% significance level), we reject the null hypothesis and conclude that the customer service department's claim is true (the response time is less than 5 minutes).\n- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no sufficient evidence to support the claim that the average response time is less than 5 minutes.\n"

# %%
"""
15. A company is testing two different website layouts to see which one leads to higher click-through rates. 
Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value. Use the following data:
```python
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]
"""

import numpy as np
from scipy import stats

# Data for the A/B test
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

# Perform the two-sample t-test
t_stat, p_value = stats.ttest_ind(layout_a_clicks, layout_b_clicks)

# Calculate degrees of freedom
n1 = len(layout_a_clicks)
n2 = len(layout_b_clicks)
degrees_of_freedom = n1 + n2 - 2

# Output results
print(f"T-statistic: {t_stat}")
print(f"Degrees of freedom: {degrees_of_freedom}")
print(f"P-value: {p_value}")

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between Layout A and Layout B.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between Layout A and Layout B.")

    
"""
Interpretation:
- If the p-value is less than 0.05, we reject the null hypothesis and conclude that there is a significant difference between the two layouts.
- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no significant difference between the click-through rates of Layout A and Layout B.
"""
# Out:
# T-statistic: -7.298102156175071
# Degrees of freedom: 18
# P-value: 8.833437608301987e-07
# Reject the null hypothesis. There is a significant difference between Layout A and Layout B.
# '\nInterpretation:\n- If the p-value is less than 0.05, we reject the null hypothesis and conclude that there is a significant difference between the two layouts.\n- If the p-value is greater than 0.05, we fail to reject the null hypothesis, meaning there is no significant difference between the click-through rates of Layout A and Layout B.\n'

# %%
"""
16. A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in reducing cholesterol levels. 
Create a program to analyze the clinical trial data and calculate the t-statistic and p-value for the treatment effect.
Use the following data of cholestrol level:
```python
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]
"""

import numpy as np
from scipy import stats

# Cholesterol levels for the existing and new drugs
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

# Perform the two-sample t-test
t_stat, p_value = stats.ttest_ind(existing_drug_levels, new_drug_levels)

# Calculate degrees of freedom
n1 = len(existing_drug_levels)
n2 = len(new_drug_levels)
degrees_of_freedom = n1 + n2 - 2

# Output results
print(f"T-statistic: {t_stat:.4f}")
print(f"Degrees of freedom: {degrees_of_freedom}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in cholesterol levels between the existing drug and the new drug.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in cholesterol levels between the existing drug and the new drug.")

    
"""
Interpretation:
- If the p-value is less than 0.05, you reject the null hypothesis and conclude that there is a significant difference in cholesterol levels between the existing and new drugs.
- If the p-value is greater than 0.05, you fail to reject the null hypothesis, meaning there is no significant difference in cholesterol levels between the two drugs.
"""
# Out:
# T-statistic: 4.1405
# Degrees of freedom: 18
# P-value: 0.0006
# Reject the null hypothesis. There is a significant difference in cholesterol levels between the existing drug and the new drug.
# '\nInterpretation:\n- If the p-value is less than 0.05, you reject the null hypothesis and conclude that there is a significant difference in cholesterol levels between the existing and new drugs.\n- If the p-value is greater than 0.05, you fail to reject the null hypothesis, meaning there is no significant difference in cholesterol levels between the two drugs.\n'

# %%
"""
17. A school district introduces an educational intervention program to improve math scores. 
Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to determine if the intervention had a significant impact. 
Use the following data of test score:
```python
pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
"""

import numpy as np
from scipy import stats

def analyze_intervention(pre_scores, post_scores):
    # Perform the paired t-test
    t_stat, p_value = stats.ttest_rel(pre_scores, post_scores)

    # Output results
    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis. The intervention had a significant impact on test scores.")
    else:
        print("Fail to reject the null hypothesis. The intervention did not have a significant impact on test scores.")

# Data: Pre- and Post-Intervention Test Scores
pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

# Analyze the impact of the intervention
analyze_intervention(pre_intervention_scores, post_intervention_scores)


"""
Interpretation:
- If the p-value is less than 0.05, you reject the null hypothesis, indicating that the intervention had a significant impact on test scores.
- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting that the intervention did not have a significant effect on test scores.
"""
# Out:
# T-statistic: -4.4284
# P-value: 0.0017
# Reject the null hypothesis. The intervention had a significant impact on test scores.
# '\nInterpretation:\n- If the p-value is less than 0.05, you reject the null hypothesis, indicating that the intervention had a significant impact on test scores.\n- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting that the intervention did not have a significant effect on test scores.\n'

# %%
"""
18. An HR department wants to investigate if there's a gender-based salary gap within the company. 
Develop a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically significant difference between the average salaries of male and female employees. 
Use the below code to generate synthetic data:
```python
# Generate synthetic salary data for male and female employees
np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)
```
"""

import numpy as np
from scipy import stats

def analyze_salary_gap(male_salaries, female_salaries):
    # Perform the independent two-sample t-test
    t_stat, p_value = stats.ttest_ind(male_salaries, female_salaries)

    # Output results
    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis. There is a significant difference in average salaries between male and female employees.")
    else:
        print("Fail to reject the null hypothesis. There is no significant difference in average salaries between male and female employees.")

# Generate synthetic salary data
np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

# Analyze the salary gap
analyze_salary_gap(male_salaries, female_salaries)



"""
Interpretation:
- If the p-value is less than 0.05, you reject the null hypothesis, suggesting a significant salary gap between male and female employees.
- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting no significant difference in average salaries.
"""
# Out:
# T-statistic: 0.0611
# P-value: 0.9516
# Fail to reject the null hypothesis. There is no significant difference in average salaries between male and female employees.
# '\nInterpretation:\n- If the p-value is less than 0.05, you reject the null hypothesis, suggesting a significant salary gap between male and female employees.\n- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting no significant difference in average salaries.\n'

# %%
"""
19. A manufacturer produces two different versions of a product and wants to compare their quality scores. Create a Python function to analyze quality assessment data, calculate the t-statistic, and decide 
whether there's a significant difference in quality between the two versions. Use the following data:
```python
version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]
```
"""

import numpy as np
from scipy import stats

def analyze_quality_scores(version1_scores, version2_scores):
    # Perform the independent two-sample t-test
    t_stat, p_value = stats.ttest_ind(version1_scores, version2_scores)

    # Output results
    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis. There is a significant difference in quality scores between the two versions.")
    else:
        print("Fail to reject the null hypothesis. There is no significant difference in quality scores between the two versions.")

# Quality scores for two versions of the product
version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

# Analyze the quality scores
analyze_quality_scores(version1_scores, version2_scores)



"""
Interpretation:
- If the p-value is less than 0.05, you reject the null hypothesis, suggesting a significant difference in quality scores between the two versions.
- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting no significant difference in quality scores.
"""
# Out:
# T-statistic: 11.3258
# P-value: 0.0000
# Reject the null hypothesis. There is a significant difference in quality scores between the two versions.
# '\nInterpretation:\n- If the p-value is less than 0.05, you reject the null hypothesis, suggesting a significant difference in quality scores between the two versions.\n- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting no significant difference in quality scores.\n'

# %%
"""
20. A restaurant chain collects customer satisfaction scores for two different branches. 
Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in 
customer satisfaction between the branches. Use the below data of scores:
```python
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]
"""

import numpy as np
from scipy import stats

def analyze_satisfaction_scores(branch_a_scores, branch_b_scores):
    # Perform the independent two-sample t-test
    t_stat, p_value = stats.ttest_ind(branch_a_scores, branch_b_scores)

    # Output results
    print(f"T-statistic: {t_stat:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis. There is a significant difference in customer satisfaction scores between the two branches.")
    else:
        print("Fail to reject the null hypothesis. There is no significant difference in customer satisfaction scores between the two branches.")

# Customer satisfaction scores for two branches
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

# Analyze the satisfaction scores
analyze_satisfaction_scores(branch_a_scores, branch_b_scores)


"""
Interpretation:
- If the p-value is less than 0.05, you reject the null hypothesis, suggesting a significant difference in customer satisfaction scores between the two branches.
- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting no significant difference in customer satisfaction scores.
"""
# Out:
# T-statistic: 5.4801
# P-value: 0.0000
# Reject the null hypothesis. There is a significant difference in customer satisfaction scores between the two branches.
# '\nInterpretation:\n- If the p-value is less than 0.05, you reject the null hypothesis, suggesting a significant difference in customer satisfaction scores between the two branches.\n- If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting no significant difference in customer satisfaction scores.\n'

# %%
"""
21. A political analyst wants to determine if there is a significant association between age groups and voter preferences (Candidate A or Candidate B). 
They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences. 
Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences. 
Use the below code to generate data:
```python
np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+', '51+'], size=30)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)
"""

import numpy as np
import pandas as pd
from scipy import stats

# Generate synthetic data
np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

# Create a DataFrame
data = pd.DataFrame({'Age Group': age_groups, 'Voter Preference': voter_preferences})

# Create a contingency table
contingency_table = pd.crosstab(data['Age Group'], data['Voter Preference'])

# Perform Chi-Square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(contingency_table)

# Output results
print("Contingency Table:")
print(contingency_table)
print(f"\nChi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("\nReject the null hypothesis. There is a significant association between age groups and voter preferences.")
else:
    print("\nFail to reject the null hypothesis. There is no significant association between age groups and voter preferences.")

    

"""
Interpretation:
- P-value: If the p-value is less than the significance level (0.05), you reject the null hypothesis, suggesting a significant association between age groups and voter preferences.
- Contingency Table: Shows how the data is distributed across the categories.
"""
# Out:
# Contingency Table:
# Voter Preference  Candidate A  Candidate B
# Age Group
# 18-30                      68           59
# 31-50                      59           63
# 51+                       131          120
#
# Chi-Square Statistic: 0.7398
# P-value: 0.6908
# Degrees of Freedom: 2
#
# Fail to reject the null hypothesis. There is no significant association between age groups and voter preferences.
# '\nInterpretation:\n- P-value: If the p-value is less than the significance level (0.05), you reject the null hypothesis, suggesting a significant association between age groups and voter preferences.\n- Contingency Table: Shows how the data is distributed across the categories.\n'

# %%
"""
22. A company conducted a customer satisfaction survey to determine if there is a significant relationship between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are 
located (East, West, North, South). The survey data is summarized in a contingency table. 
Conduct a Chi Square test to determine if there is a significant relationship between product satisfaction levels and customer regions.
Sample data:
```python
```
#Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])
"""

import numpy as np
from scipy import stats

# Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

# Perform Chi-Square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data)

# Output results
print("Contingency Table:")
print(data)
print(f"\nChi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies Table:\n{expected}")

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("\nReject the null hypothesis. There is a significant relationship between product satisfaction levels and customer regions.")
else:
    print("\nFail to reject the null hypothesis. There is no significant relationship between product satisfaction levels and customer regions.")

    
"""
Interpretation:
- Compare the p-value to the significance level (α = 0.05). If the p-value is less than 0.05, there is a significant relationship between the satisfaction levels and customer regions.
Otherwise, there is no significant relationship.
"""
# Out:
# Contingency Table:
# [[50 30 40 20]
#  [30 40 30 50]
#  [20 30 40 30]]
#
# Chi-Square Statistic: 27.7771
# P-value: 0.0001
# Degrees of Freedom: 6
# Expected Frequencies Table:
# [[34.14634146 34.14634146 37.56097561 34.14634146]
#  [36.58536585 36.58536585 40.24390244 36.58536585]
#  [29.26829268 29.26829268 32.19512195 29.26829268]]
#
# Reject the null hypothesis. There is a significant relationship between product satisfaction levels and customer regions.
# '\nInterpretation:\n- Compare the p-value to the significance level (α = 0.05). If the p-value is less than 0.05, there is a significant relationship between the satisfaction levels and customer regions.\nOtherwise, there is no significant relationship.\n'

# %%
"""
23. A company implemented an employee training program to improve job performance (Effective, Neutral, Ineffective). 
After the training, they collected data from a sample of employees and classified them based on their job performance before and after the training. 
Perform a Chi-Square test to determine if there is a significant difference between job performance levels before and after the training.
Sample data:
```python
# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])
```
"""

import numpy as np
from scipy import stats

# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

# Perform Chi-Square test
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data)

# Output results
print("Contingency Table:")
print(data)
print(f"\nChi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print(f"Expected Frequencies Table:\n{expected}")

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("\nReject the null hypothesis. There is a significant difference in job performance levels before and after the training.")
else:
    print("\nFail to reject the null hypothesis. There is no significant difference in job performance levels before and after the training.")

    
    
"""
Interpretation:
- Compare the p-value to the significance level (α = 0.05). If the p-value is less than 0.05, there is a significant difference in job performance levels before and after the training. 
Otherwise, there is no significant difference.
"""
# Out:
# Contingency Table:
# [[50 30 20]
#  [30 40 30]
#  [20 30 40]]
#
# Chi-Square Statistic: 22.1617
# P-value: 0.0002
# Degrees of Freedom: 4
# Expected Frequencies Table:
# [[34.48275862 34.48275862 31.03448276]
#  [34.48275862 34.48275862 31.03448276]
#  [31.03448276 31.03448276 27.93103448]]
#
# Reject the null hypothesis. There is a significant difference in job performance levels before and after the training.
# '\nInterpretation:\n- Compare the p-value to the significance level (α = 0.05). If the p-value is less than 0.05, there is a significant difference in job performance levels before and after the training. \nOtherwise, there is no significant difference.\n'

# %%
"""
24. A company produces three different versions of a product: Standard, Premium, and Deluxe. 
The company wants to determine if there is a significant difference in customer satisfaction scores among the three product versions. 
They conducted a survey and collected customer satisfaction scores for each version from a random sample of customers. 
Perform an ANOVA test to determine if there is a significant difference in customer satisfaction scores. Use the following data:
```python
# Sample data: Customer satisfaction scores for each product version
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]
```
"""

import numpy as np
from scipy import stats

# Sample data: Customer satisfaction scores for each product version
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# Perform ANOVA test
f_stat, p_value = stats.f_oneway(standard_scores, premium_scores, deluxe_scores)

# Output results
print("ANOVA Test Results:")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # significance level
if p_value < alpha:
    print("\nReject the null hypothesis. There is a significant difference in customer satisfaction scores among the three product versions.")
else:
    print("\nFail to reject the null hypothesis. There is no significant difference in customer satisfaction scores among the three product versions.")



"""
Interpretation:
- Compare the p-value to the significance level (α = 0.05). If the p-value is less than 0.05, you reject the null hypothesis, indicating a significant difference in customer satisfaction scores among the product versions.
If the p-value is greater than 0.05, you fail to reject the null hypothesis, meaning there is no significant difference.
"""
# Out:
# ANOVA Test Results:
# F-statistic: 27.0356
# P-value: 0.0000
#
# Reject the null hypothesis. There is a significant difference in customer satisfaction scores among the three product versions.
# '\nInterpretation:\n- Compare the p-value to the significance level (α = 0.05). If the p-value is less than 0.05, you reject the null hypothesis, indicating a significant difference in customer satisfaction scores among the product versions.\nIf the p-value is greater than 0.05, you fail to reject the null hypothesis, meaning there is no significant difference.\n'
